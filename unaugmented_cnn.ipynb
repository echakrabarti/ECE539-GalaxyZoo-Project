# %%
from preprocessing import get_datasets
from model_helper import *
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %%
train_dataset, validation_dataset, test_dataset = get_datasets(32, augment=False)

# %%
model = Sequential([
    Conv2D(32, (6, 6), activation='relu', input_shape=(69, 69, 3)),
    Conv2D(64, (5, 5), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(3, 3)),
    Flatten(),
    Dense(2048, activation='relu'),
    Dense(2048, activation='relu'),
    Dense(37, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_4 (Conv2D)           (None, 64, 64, 32)        3488
#
#  conv2d_5 (Conv2D)           (None, 60, 60, 64)        51264
#
#  max_pooling2d_3 (MaxPoolin  (None, 30, 30, 64)        0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 28, 28, 128)       73856
#
#  max_pooling2d_4 (MaxPoolin  (None, 14, 14, 128)       0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 12, 12, 128)       147584
#
#  max_pooling2d_5 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dense_3 (Dense)             (None, 2048)              4196352
#
#  dense_4 (Dense)             (None, 2048)              4196352
#
#  dense_5 (Dense)             (None, 37)                75813
#
# ...
# Total params: 8744709 (33.36 MB)
# Trainable params: 8744709 (33.36 MB)
# Non-trainable params: 0 (0.00 Byte)
# ...

# %%
history = compile_and_fit(model, train_dataset, validation_dataset, 25)
plot_history(history, 'unaugmented_cnn')
# Out:
# Epoch 1/25
# 1540/1540 [==============================] - 17s 10ms/step - loss: 0.2652 - accuracy: 0.6640 - root_mean_squared_error: 0.1289 - val_loss: 0.2541 - val_accuracy: 0.7057 - val_root_mean_squared_error: 0.1178
# Epoch 2/25
# 1540/1540 [==============================] - 15s 10ms/step - loss: 0.2491 - accuracy: 0.7378 - root_mean_squared_error: 0.1107 - val_loss: 0.2460 - val_accuracy: 0.7485 - val_root_mean_squared_error: 0.1074
# Epoch 3/25
# 1540/1540 [==============================] - 15s 10ms/step - loss: 0.2464 - accuracy: 0.7447 - root_mean_squared_error: 0.1069 - val_loss: 0.2459 - val_accuracy: 0.7467 - val_root_mean_squared_error: 0.1074
# Epoch 4/25
# 1540/1540 [==============================] - 15s 10ms/step - loss: 0.2441 - accuracy: 0.7526 - root_mean_squared_error: 0.1036 - val_loss: 0.2448 - val_accuracy: 0.7358 - val_root_mean_squared_error: 0.1057
# Epoch 5/25
# ...

# %%
submit(model, test_dataset, 'unaugmented_cnn')
# Out:
# 2500/2500 [==============================] - 7s 3ms/step
